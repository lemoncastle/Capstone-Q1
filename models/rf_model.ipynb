# %%
import numpy as np
import netCDF4
import pandas as pd
import xarray as xr
from eofs.xarray import Eof
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.feature_selection import RFE
from sklearn import metrics
from sklearn.ensemble import RandomForestRegressor 
from sklearn.model_selection import RandomizedSearchCV
from esem import rf_model
from esem.utils import leave_one_out
import joblib

# data_path = './data/train_val/'
data_path = "/glade/u/home/okyang/input_data/"

min_co2 = 0.
max_co2 = 9500
def normalize_co2(data):
    return data / max_co2

def un_normalize_co2(data):
    return data * max_co2

min_ch4 = 0.
max_ch4 = 0.8
def normalize_ch4(data):
    return data / max_ch4

def un_normalize_ch4(data):
    return data * max_ch4


def create_predictor_data(data_sets, n_eofs=5):
    """
    Args:
        data_sets list(str): names of datasets
        n_eofs (int): number of eofs to create for aerosol variables
    """
        
    # Create training and testing arrays
    if isinstance(data_sets, str):
        data_sets = [data_sets]
    X = xr.concat([xr.open_dataset(data_path + f"inputs_{file}.nc") for file in data_sets], dim='time')
    X = X.assign_coords(time=np.arange(len(X.time)))

    # Compute EOFs for BC
    bc_solver = Eof(X['BC'])
    bc_eofs = bc_solver.eofsAsCorrelation(neofs=n_eofs)
    bc_pcs = bc_solver.pcs(npcs=n_eofs, pcscaling=1)

    # Compute EOFs for SO2
    so2_solver = Eof(X['SO2'])
    so2_eofs = so2_solver.eofsAsCorrelation(neofs=n_eofs)
    so2_pcs = so2_solver.pcs(npcs=n_eofs, pcscaling=1)

    # Convert to pandas
    bc_df = bc_pcs.to_dataframe().unstack('mode')
    bc_df.columns = [f"BC_{i}" for i in range(n_eofs)]

    so2_df = so2_pcs.to_dataframe().unstack('mode')
    so2_df.columns = [f"SO2_{i}" for i in range(n_eofs)]

    # Bring the emissions data back together again and normalise
    inputs = pd.DataFrame({
        "CO2": normalize_co2(X["CO2"].data),
        "CH4": normalize_ch4(X["CH4"].data)
    }, index=X["CO2"].coords['time'].data)

    # Combine with aerosol EOFs
    inputs = pd.concat([inputs, bc_df, so2_df], axis=1)
    return inputs, (so2_solver, bc_solver)


def get_test_data(file, eof_solvers, n_eofs=5):
    """
    Args:
        file str: name of datasets
        n_eofs (int): number of eofs to create for aerosol variables
        eof_solvers (Eof_so2, Eof_bc): Fitted Eof objects to use for projection
    """
        
    # Create training and testing arrays
    X = xr.open_dataset(data_path + f"inputs_{file}.nc")
        
    so2_pcs = eof_solvers[0].projectField(X["SO2"], neofs=5, eofscaling=1)
    so2_df = so2_pcs.to_dataframe().unstack('mode')
    so2_df.columns = [f"SO2_{i}" for i in range(n_eofs)]

    bc_pcs = eof_solvers[1].projectField(X["BC"], neofs=5, eofscaling=1)
    bc_df = bc_pcs.to_dataframe().unstack('mode')
    bc_df.columns = [f"BC_{i}" for i in range(n_eofs)]

    # Bring the emissions data back together again and normalise
    inputs = pd.DataFrame({
        "CO2": normalize_co2(X["CO2"].data),
        "CH4": normalize_ch4(X["CH4"].data)
    }, index=X["CO2"].coords['time'].data)

    # Combine with aerosol EOFs
    inputs = pd.concat([inputs, bc_df, so2_df], axis=1)
    return inputs


def create_predictdand_data(data_sets):
    if isinstance(data_sets, str):
        data_sets = [data_sets]
    Y = xr.concat([xr.open_dataset(data_path + f"outputs_{file}.nc") for file in data_sets], dim='time').mean("member")
    # Convert the precip values to mm/day
    Y["pr"] *= 86400
    Y["pr90"] *= 86400
    return Y


def get_rmse(truth, pred):
    weights = np.cos(np.deg2rad(truth.lat))
    return np.sqrt(((truth - pred)**2).weighted(weights).mean(['lat', 'lon'])).data
# Out:
# 2025-11-24 18:33:58.740891: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-24 18:33:59.191355: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-24 18:34:08.726527: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
train_files = ["historical", "ssp126", "ssp370", 'hist-aer', 'hist-GHG']
tasFiles = ["historical", "ssp126", "ssp370", "hist-aer", "hist-GHG"]
# Create training and testing arrays
X, solvers = create_predictor_data(train_files)
Y = create_predictdand_data(tasFiles)

# %%
rfTas = RandomForestRegressor(random_state=0)
rfPr = RandomForestRegressor(random_state=0)
rfPr90 = RandomForestRegressor(random_state=0)
rfDTR = RandomForestRegressor(random_state=0)

# %%
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 300, num = 5)]
# Number of features to consider at every split
max_features = ['sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5,55, num = 11)]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [5, 10, 15, 25]
# Minimum number of samples required at each leaf node
min_samples_leaf = [4, 8, 12]
# Method of selecting samples for training each tree
bootstrap = [True, False]

# %%
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}

# %%
rfTasRandom = RandomizedSearchCV(estimator = rfTas, param_distributions = random_grid, n_iter = 29, cv = 3, verbose=2, n_jobs = -1)
rfPrRandom = RandomizedSearchCV(estimator = rfPr, param_distributions = random_grid, n_iter = 29, cv = 3, verbose=2, n_jobs = -1)
rfPr90Random = RandomizedSearchCV(estimator = rfPr90, param_distributions = random_grid, n_iter = 29, cv = 3, verbose=2, n_jobs = -1)
rfDTRRandom = RandomizedSearchCV(estimator = rfDTR, param_distributions = random_grid, n_iter = 29, cv = 3, verbose=2, n_jobs = -1)

# %%
Y.compute()
# Out:
# <xarray.Dataset> Size: 184MB
# Dimensions:                    (time: 667, lat: 96, lon: 144)
# Coordinates:
#   * lat                        (lat) float64 768B -90.0 -88.11 ... 88.11 90.0
#   * lon                        (lon) float64 1kB 0.0 2.5 5.0 ... 355.0 357.5
#   * time                       (time) int64 5kB 1850 1851 1852 ... 2013 2014
#     quantile                   float64 8B 0.9
# Data variables:
#     diurnal_temperature_range  (time, lat, lon) float32 37MB 0.03264 ... -0.3354
#     tas                        (time, lat, lon) float32 37MB 0.32 ... 2.611
#     pr                         (time, lat, lon) float32 37MB 0.02337 ... 0.04197
#     pr90                       (time, lat, lon) float64 74MB 0.02468 ... 0.08654

# %%
y_inp_tas  = Y["tas"].stack(space=("lat", "lon"))
y_inp_pr   = Y["pr"].stack(space=("lat", "lon"))
y_inp_pr90 = Y["pr90"].stack(space=("lat", "lon"))
y_inp_dtr  = Y["diurnal_temperature_range"].stack(space=("lat", "lon"))

# %%
rf_tas = rfTasRandom.fit(X, y_inp_tas)
# Out:
# Fitting 3 folds for each of 29 candidates, totalling 87 fits
# [CV] END bootstrap=True, max_depth=55, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time=  51.2s
# [CV] END bootstrap=False, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=15, n_estimators=100; total time=  30.4s
# /glade/u/home/okyang/.local/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [CV] END bootstrap=True, max_depth=55, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time=  45.8s
# [CV] END bootstrap=False, max_depth=40, max_features=sqrt, min_samples_leaf=12, min_samples_split=5, n_estimators=250; total time=  59.0s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=8, min_samples_split=25, n_estimators=100; total time=  14.3s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=8, min_samples_split=25, n_estimators=100; total time=  14.7s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=8, min_samples_split=25, n_estimators=100; total time=  16.0s
# [CV] END bootstrap=False, max_depth=40, max_features=sqrt, min_samples_leaf=12, min_samples_split=5, n_estimators=250; total time= 1.0min
# [CV] END bootstrap=True, max_depth=55, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time=  46.8s
# [CV] END bootstrap=False, max_depth=40, max_features=sqrt, min_samples_leaf=12, min_samples_split=5, n_estimators=250; total time= 1.1min
# [CV] END bootstrap=False, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=15, n_estimators=100; total time=  29.1s
# [CV] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=200; total time=  58.9s
# [CV] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=200; total time=  54.3s
# [CV] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=250; total time=  47.2s
# [CV] END bootstrap=False, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=15, n_estimators=100; total time=  32.5s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=8, min_samples_split=25, n_estimators=150; total time=  21.2s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=8, min_samples_split=25, n_estimators=150; total time=  22.3s
# [CV] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=250; total time=  53.4s
# [CV] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=200; total time=  55.4s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=8, min_samples_split=25, n_estimators=150; total time=  23.9s
# [CV] END bootstrap=True, max_depth=25, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  54.5s
# [CV] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=250; total time=  48.0s
# [CV] END bootstrap=True, max_depth=25, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time= 1.0min
# [CV] END bootstrap=True, max_depth=25, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=300; total time=  55.1s
# [CV] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=25, n_estimators=200; total time=  51.9s
# [CV] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=25, n_estimators=200; total time=  58.0s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=8, min_samples_split=5, n_estimators=300; total time=  46.7s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=12, min_samples_split=5, n_estimators=200; total time=  24.0s
# [CV] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=25, n_estimators=200; total time=  54.9s
# [CV] END bootstrap=False, max_depth=55, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=150; total time=  50.7s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=8, min_samples_split=5, n_estimators=300; total time=  47.1s
# [CV] END bootstrap=False, max_depth=55, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=150; total time=  48.6s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=8, min_samples_split=5, n_estimators=300; total time=  50.3s
# [CV] END bootstrap=False, max_depth=25, max_features=sqrt, min_samples_leaf=12, min_samples_split=15, n_estimators=100; total time=  24.4s
# [CV] END bootstrap=False, max_depth=25, max_features=sqrt, min_samples_leaf=12, min_samples_split=15, n_estimators=100; total time=  26.4s
# [CV] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=12, min_samples_split=5, n_estimators=150; total time=  20.4s
# [CV] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=12, min_samples_split=5, n_estimators=150; total time=  22.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  18.6s
# [CV] END bootstrap=False, max_depth=55, max_features=sqrt, min_samples_leaf=4, min_samples_split=25, n_estimators=150; total time=  43.7s
# [CV] END bootstrap=False, max_depth=45, max_features=sqrt, min_samples_leaf=8, min_samples_split=25, n_estimators=100; total time=  24.9s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  21.1s
# [CV] END bootstrap=False, max_depth=45, max_features=sqrt, min_samples_leaf=8, min_samples_split=5, n_estimators=250; total time= 1.1min
# [CV] END bootstrap=True, max_depth=45, max_features=sqrt, min_samples_leaf=12, min_samples_split=5, n_estimators=250; total time=  33.8s
# [CV] END bootstrap=False, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=15, n_estimators=300; total time= 1.5min
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=12, min_samples_split=5, n_estimators=200; total time=  24.3s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=12, min_samples_split=5, n_estimators=200; total time=  27.5s
# [CV] END bootstrap=True, max_depth=45, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=100; total time=  15.4s
# [CV] END bootstrap=True, max_depth=45, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=100; total time=  15.3s
# [CV] END bootstrap=True, max_depth=45, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=100; total time=  17.2s
# [CV] END bootstrap=False, max_depth=55, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=150; total time=  55.7s
# [CV] END bootstrap=False, max_depth=25, max_features=sqrt, min_samples_leaf=12, min_samples_split=15, n_estimators=100; total time=  24.1s
# [CV] END bootstrap=False, max_depth=55, max_features=sqrt, min_samples_leaf=4, min_samples_split=25, n_estimators=150; total time=  41.8s
# [CV] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=12, min_samples_split=5, n_estimators=150; total time=  20.6s
# [CV] END bootstrap=False, max_depth=45, max_features=sqrt, min_samples_leaf=8, min_samples_split=25, n_estimators=100; total time=  28.1s
# [CV] END bootstrap=False, max_depth=15, max_features=sqrt, min_samples_leaf=12, min_samples_split=10, n_estimators=200; total time=  53.6s
# [CV] END bootstrap=True, max_depth=45, max_features=sqrt, min_samples_leaf=12, min_samples_split=5, n_estimators=250; total time=  34.2s
# [CV] END bootstrap=True, max_depth=45, max_features=sqrt, min_samples_leaf=12, min_samples_split=5, n_estimators=250; total time=  37.5s
# [CV] END bootstrap=False, max_depth=45, max_features=sqrt, min_samples_leaf=12, min_samples_split=10, n_estimators=250; total time= 1.0min
# [CV] END bootstrap=False, max_depth=45, max_features=sqrt, min_samples_leaf=12, min_samples_split=10, n_estimators=250; total time= 1.0min
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time= 1.5min
# [CV] END bootstrap=False, max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=25, n_estimators=150; total time=  30.5s
# [CV] END bootstrap=False, max_depth=40, max_features=sqrt, min_samples_leaf=12, min_samples_split=10, n_estimators=200; total time=  48.1s
# [CV] END bootstrap=False, max_depth=45, max_features=sqrt, min_samples_leaf=12, min_samples_split=10, n_estimators=250; total time= 1.1min
# [CV] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  36.4s
# [CV] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=8, min_samples_split=5, n_estimators=200; total time=  30.4s
# [CV] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=8, min_samples_split=5, n_estimators=200; total time=  34.4s
# [CV] END bootstrap=False, max_depth=40, max_features=sqrt, min_samples_leaf=12, min_samples_split=10, n_estimators=200; total time=  52.6s
# [CV] END bootstrap=False, max_depth=15, max_features=sqrt, min_samples_leaf=12, min_samples_split=10, n_estimators=200; total time=  48.0s
# [CV] END bootstrap=False, max_depth=45, max_features=sqrt, min_samples_leaf=8, min_samples_split=5, n_estimators=250; total time= 1.1min
# [CV] END bootstrap=False, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=15, n_estimators=300; total time= 1.5min
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time= 1.4min
# [CV] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  37.1s
# [CV] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=8, min_samples_split=5, n_estimators=200; total time=  30.8s
# [CV] END bootstrap=False, max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=25, n_estimators=150; total time=  34.4s
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=8, min_samples_split=25, n_estimators=150; total time=  38.5s
# [CV] END bootstrap=False, max_depth=55, max_features=sqrt, min_samples_leaf=4, min_samples_split=25, n_estimators=150; total time=  39.3s
# [CV] END bootstrap=False, max_depth=45, max_features=sqrt, min_samples_leaf=8, min_samples_split=25, n_estimators=100; total time=  25.5s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  19.0s
# [CV] END bootstrap=False, max_depth=15, max_features=sqrt, min_samples_leaf=12, min_samples_split=10, n_estimators=200; total time=  47.4s
# [CV] END bootstrap=False, max_depth=45, max_features=sqrt, min_samples_leaf=8, min_samples_split=5, n_estimators=250; total time= 1.2min
# [CV] END bootstrap=False, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=15, n_estimators=300; total time= 1.6min
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time= 1.3min
# [CV] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  40.3s
# [CV] END bootstrap=False, max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=25, n_estimators=150; total time=  31.3s
# [CV] END bootstrap=False, max_depth=40, max_features=sqrt, min_samples_leaf=12, min_samples_split=10, n_estimators=200; total time=  48.8s
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=8, min_samples_split=25, n_estimators=150; total time=  36.5s
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=8, min_samples_split=25, n_estimators=150; total time=  39.7s

# %%
joblib.dump(rf_tas, "model.pkl")
# Out:
# ['model.pkl']

# %%
rf_pr = rfPrRandom.fit(X, y_inp_pr)
# Out:
# Fitting 3 folds for each of 29 candidates, totalling 87 fits
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=150; total time=  30.1s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=15, n_estimators=300; total time=  40.6s
# /glade/u/home/okyang/.local/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=150; total time=  32.2s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=15, n_estimators=300; total time=  40.1s
# [CV] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=12, min_samples_split=10, n_estimators=100; total time=  25.4s
# [CV] END bootstrap=False, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  49.2s
# [CV] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=12, min_samples_split=5, n_estimators=200; total time=  46.1s
# [CV] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=12, min_samples_split=10, n_estimators=100; total time=  23.1s
# [CV] END bootstrap=False, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  44.1s
# [CV] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=4, min_samples_split=15, n_estimators=250; total time= 1.5min
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=150; total time=  29.9s
# [CV] END bootstrap=True, max_depth=40, max_features=sqrt, min_samples_leaf=4, min_samples_split=15, n_estimators=150; total time=  30.0s
# [CV] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=12, min_samples_split=10, n_estimators=100; total time=  23.0s
# [CV] END bootstrap=False, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  44.4s
# [CV] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=4, min_samples_split=15, n_estimators=250; total time= 1.3min
# [CV] END bootstrap=True, max_depth=45, max_features=sqrt, min_samples_leaf=4, min_samples_split=25, n_estimators=300; total time=  48.8s
# [CV] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=12, min_samples_split=5, n_estimators=200; total time=  51.0s
# [CV] END bootstrap=False, max_depth=55, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  33.5s
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=15, n_estimators=300; total time= 1.6min
# [CV] END bootstrap=False, max_depth=55, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  33.4s
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=15, n_estimators=300; total time= 1.7min
# [CV] END bootstrap=True, max_depth=35, max_features=sqrt, min_samples_leaf=4, min_samples_split=25, n_estimators=250; total time=  45.5s
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=8, min_samples_split=10, n_estimators=100; total time=  27.0s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=25, n_estimators=150; total time=  25.7s
# [CV] END bootstrap=True, max_depth=25, max_features=sqrt, min_samples_leaf=12, min_samples_split=5, n_estimators=250; total time=  37.3s
# [CV] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=25, n_estimators=200; total time=  57.6s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=25, n_estimators=100; total time=  12.7s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=25, n_estimators=100; total time=  12.7s
# [CV] END bootstrap=True, max_depth=25, max_features=sqrt, min_samples_leaf=12, min_samples_split=5, n_estimators=150; total time=  20.2s
# [CV] END bootstrap=True, max_depth=55, max_features=sqrt, min_samples_leaf=12, min_samples_split=10, n_estimators=250; total time=  37.3s
# [CV] END bootstrap=True, max_depth=55, max_features=sqrt, min_samples_leaf=8, min_samples_split=10, n_estimators=100; total time=  15.2s
# [CV] END bootstrap=True, max_depth=55, max_features=sqrt, min_samples_leaf=8, min_samples_split=10, n_estimators=100; total time=  15.4s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=8, min_samples_split=10, n_estimators=200; total time=  30.4s
# [CV] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=4, min_samples_split=25, n_estimators=150; total time=  25.3s
# [CV] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 1.9min
# [CV] END bootstrap=True, max_depth=35, max_features=sqrt, min_samples_leaf=4, min_samples_split=25, n_estimators=250; total time=  41.3s
# [CV] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=12, min_samples_split=10, n_estimators=200; total time=  27.0s
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=8, min_samples_split=10, n_estimators=100; total time=  30.2s
# [CV] END bootstrap=True, max_depth=25, max_features=sqrt, min_samples_leaf=12, min_samples_split=5, n_estimators=250; total time=  31.9s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=8, min_samples_split=25, n_estimators=200; total time=  28.7s
# [CV] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=25, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=25, n_estimators=100; total time=  13.9s
# [CV] END bootstrap=True, max_depth=25, max_features=sqrt, min_samples_leaf=12, min_samples_split=5, n_estimators=150; total time=  22.1s
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=12, min_samples_split=5, n_estimators=200; total time=  47.0s
# [CV] END bootstrap=True, max_depth=55, max_features=sqrt, min_samples_leaf=8, min_samples_split=10, n_estimators=100; total time=  16.7s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=8, min_samples_split=10, n_estimators=200; total time=  34.4s
# [CV] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 1.7min
# [CV] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=8, min_samples_split=5, n_estimators=150; total time=  39.9s
# [CV] END bootstrap=True, max_depth=40, max_features=sqrt, min_samples_leaf=4, min_samples_split=15, n_estimators=150; total time=  26.7s
# [CV] END bootstrap=True, max_depth=40, max_features=sqrt, min_samples_leaf=4, min_samples_split=15, n_estimators=150; total time=  28.3s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=15, n_estimators=300; total time=  46.5s
# [CV] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=4, min_samples_split=15, n_estimators=250; total time= 1.3min
# [CV] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=12, min_samples_split=5, n_estimators=200; total time=  46.5s
# [CV] END bootstrap=True, max_depth=45, max_features=sqrt, min_samples_leaf=4, min_samples_split=25, n_estimators=300; total time=  50.7s
# [CV] END bootstrap=False, max_depth=55, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=  38.0s
# [CV] END bootstrap=False, max_depth=55, max_features=sqrt, min_samples_leaf=12, min_samples_split=15, n_estimators=150; total time=  35.1s
# [CV] END bootstrap=False, max_depth=55, max_features=sqrt, min_samples_leaf=12, min_samples_split=15, n_estimators=150; total time=  35.9s
# [CV] END bootstrap=True, max_depth=35, max_features=sqrt, min_samples_leaf=4, min_samples_split=25, n_estimators=250; total time=  41.8s
# [CV] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=12, min_samples_split=10, n_estimators=200; total time=  29.6s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=25, n_estimators=150; total time=  24.4s
# [CV] END bootstrap=True, max_depth=25, max_features=sqrt, min_samples_leaf=12, min_samples_split=5, n_estimators=250; total time=  33.4s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=8, min_samples_split=25, n_estimators=200; total time=  31.9s
# [CV] END bootstrap=False, max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=150; total time=  32.2s
# [CV] END bootstrap=False, max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=150; total time=  32.0s
# [CV] END bootstrap=True, max_depth=25, max_features=sqrt, min_samples_leaf=12, min_samples_split=5, n_estimators=150; total time=  19.9s
# [CV] END bootstrap=True, max_depth=55, max_features=sqrt, min_samples_leaf=12, min_samples_split=10, n_estimators=250; total time=  34.1s
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=12, min_samples_split=5, n_estimators=200; total time=  52.0s
# [CV] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=4, min_samples_split=25, n_estimators=150; total time=  24.8s
# [CV] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=300; total time= 1.7min
# [CV] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=8, min_samples_split=5, n_estimators=150; total time=  40.0s
# [CV] END bootstrap=True, max_depth=45, max_features=sqrt, min_samples_leaf=4, min_samples_split=25, n_estimators=300; total time=  54.2s
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=15, n_estimators=300; total time= 1.6min
# [CV] END bootstrap=False, max_depth=55, max_features=sqrt, min_samples_leaf=12, min_samples_split=15, n_estimators=150; total time=  38.9s
# [CV] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=12, min_samples_split=10, n_estimators=200; total time=  26.4s
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=8, min_samples_split=10, n_estimators=100; total time=  27.1s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=25, n_estimators=150; total time=  27.9s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=8, min_samples_split=25, n_estimators=200; total time=  28.8s
# [CV] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=25, n_estimators=200; total time=  59.1s
# [CV] END bootstrap=False, max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=150; total time=  35.2s
# [CV] END bootstrap=True, max_depth=55, max_features=sqrt, min_samples_leaf=12, min_samples_split=10, n_estimators=250; total time=  32.7s
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=12, min_samples_split=5, n_estimators=200; total time=  47.2s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=8, min_samples_split=10, n_estimators=200; total time=  31.6s
# [CV] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=4, min_samples_split=25, n_estimators=150; total time=  27.4s
# [CV] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=12, min_samples_split=5, n_estimators=150; total time=  35.3s
# [CV] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=12, min_samples_split=5, n_estimators=150; total time=  36.3s
# [CV] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=12, min_samples_split=5, n_estimators=150; total time=  38.8s
# [CV] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=8, min_samples_split=5, n_estimators=150; total time=  43.0s

# %%
joblib.dump(rf_pr, "modelpr.pkl")
# Out:
# ['modelpr.pkl']

# %%
rf_pr90 = rfPr90Random.fit(X, y_inp_pr90)
# Out:
# Fitting 3 folds for each of 29 candidates, totalling 87 fits
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=12, min_samples_split=15, n_estimators=100; total time=  23.7s
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=12, min_samples_split=15, n_estimators=100; total time=  23.8s
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=12, min_samples_split=15, n_estimators=100; total time=  26.7s
# [CV] END bootstrap=False, max_depth=30, max_features=sqrt, min_samples_leaf=8, min_samples_split=10, n_estimators=200; total time=  54.9s
# /glade/u/home/okyang/.local/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time= 1.6min
# [CV] END bootstrap=False, max_depth=40, max_features=sqrt, min_samples_leaf=8, min_samples_split=5, n_estimators=150; total time=  40.3s
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time= 1.4min
# [CV] END bootstrap=False, max_depth=30, max_features=sqrt, min_samples_leaf=8, min_samples_split=10, n_estimators=200; total time= 1.0min
# [CV] END bootstrap=False, max_depth=40, max_features=sqrt, min_samples_leaf=8, min_samples_split=5, n_estimators=150; total time=  44.3s
# [CV] END bootstrap=False, max_depth=30, max_features=sqrt, min_samples_leaf=12, min_samples_split=25, n_estimators=300; total time= 1.2min
# [CV] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=250; total time= 1.5min
# [CV] END bootstrap=False, max_depth=30, max_features=sqrt, min_samples_leaf=12, min_samples_split=25, n_estimators=300; total time= 1.3min
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time= 1.4min
# [CV] END bootstrap=False, max_depth=30, max_features=sqrt, min_samples_leaf=8, min_samples_split=10, n_estimators=200; total time=  54.2s
# [CV] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=250; total time= 1.5min
# [CV] END bootstrap=False, max_depth=30, max_features=sqrt, min_samples_leaf=12, min_samples_split=25, n_estimators=300; total time= 1.2min
# [CV] END bootstrap=True, max_depth=45, max_features=sqrt, min_samples_leaf=8, min_samples_split=5, n_estimators=300; total time=  51.3s
# [CV] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=8, min_samples_split=10, n_estimators=100; total time=  15.3s
# [CV] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=8, min_samples_split=10, n_estimators=100; total time=  17.2s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=8, min_samples_split=25, n_estimators=100; total time=  25.0s
# [CV] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=8, min_samples_split=10, n_estimators=200; total time= 1.0min
# [CV] END bootstrap=True, max_depth=55, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  43.1s
# [CV] END bootstrap=True, max_depth=40, max_features=sqrt, min_samples_leaf=12, min_samples_split=5, n_estimators=300; total time=  40.6s
# [CV] END bootstrap=False, max_depth=25, max_features=sqrt, min_samples_leaf=8, min_samples_split=5, n_estimators=150; total time=  44.7s
# [CV] END bootstrap=False, max_depth=40, max_features=sqrt, min_samples_leaf=8, min_samples_split=5, n_estimators=150; total time=  39.8s
# [CV] END bootstrap=False, max_depth=50, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=250; total time= 1.6min
# [CV] END bootstrap=True, max_depth=45, max_features=sqrt, min_samples_leaf=8, min_samples_split=5, n_estimators=300; total time=  48.7s
# [CV] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=8, min_samples_split=10, n_estimators=200; total time=  53.3s
# [CV] END bootstrap=True, max_depth=55, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  38.7s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=8, min_samples_split=25, n_estimators=100; total time=  27.7s
# [CV] END bootstrap=False, max_depth=25, max_features=sqrt, min_samples_leaf=8, min_samples_split=5, n_estimators=150; total time=  40.0s
# [CV] END bootstrap=False, max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=25, n_estimators=300; total time= 1.1min
# [CV] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=25, n_estimators=100; total time=  16.1s
# [CV] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=25, n_estimators=100; total time=  16.4s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  38.6s
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=12, min_samples_split=5, n_estimators=150; total time=  35.2s
# [CV] END bootstrap=False, max_depth=30, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=100; total time=  26.8s
# [CV] END bootstrap=False, max_depth=40, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=250; total time= 1.3min
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  38.4s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=25, n_estimators=100; total time=  14.8s
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=12, min_samples_split=5, n_estimators=150; total time=  38.4s
# [CV] END bootstrap=False, max_depth=40, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=250; total time= 1.1min
# [CV] END bootstrap=False, max_depth=40, max_features=sqrt, min_samples_leaf=4, min_samples_split=15, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=8, min_samples_split=10, n_estimators=250; total time= 1.1min

# %%
joblib.dump(rf_pr90, "modelpr90.pkl")
# Out:
# ['modelpr90.pkl']

# %%
rf_dtr = rfDTRRandom.fit(X, y_inp_dtr)
# Out:
# Fitting 3 folds for each of 29 candidates, totalling 87 fits
# [CV] END bootstrap=False, max_depth=40, max_features=sqrt, min_samples_leaf=4, min_samples_split=15, n_estimators=200; total time= 1.2min
# [CV] END bootstrap=True, max_depth=35, max_features=sqrt, min_samples_leaf=12, min_samples_split=15, n_estimators=100; total time=  13.5s
# [CV] END bootstrap=True, max_depth=35, max_features=sqrt, min_samples_leaf=12, min_samples_split=15, n_estimators=100; total time=  13.7s
# [CV] END bootstrap=True, max_depth=35, max_features=sqrt, min_samples_leaf=12, min_samples_split=15, n_estimators=100; total time=  14.6s
# [CV] END bootstrap=True, max_depth=35, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=200; total time=  31.1s
# [CV] END bootstrap=True, max_depth=40, max_features=sqrt, min_samples_leaf=8, min_samples_split=10, n_estimators=200; total time=  34.9s
# [CV] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=150; total time=  28.7s
# [CV] END bootstrap=False, max_depth=5, max_features=sqrt, min_samples_leaf=12, min_samples_split=10, n_estimators=250; total time=  56.8s
# [CV] END bootstrap=False, max_depth=40, max_features=sqrt, min_samples_leaf=8, min_samples_split=5, n_estimators=150; total time=  39.3s
# [CV] END bootstrap=False, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 1.2min
# [CV] END bootstrap=False, max_depth=55, max_features=sqrt, min_samples_leaf=4, min_samples_split=25, n_estimators=150; total time=  37.8s
# [CV] END bootstrap=False, max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=25, n_estimators=300; total time= 1.1min
# [CV] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=12, min_samples_split=5, n_estimators=100; total time=  12.7s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=12, min_samples_split=15, n_estimators=300; total time=  39.6s
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=12, min_samples_split=5, n_estimators=150; total time=  35.2s
# [CV] END bootstrap=False, max_depth=30, max_features=sqrt, min_samples_leaf=12, min_samples_split=10, n_estimators=300; total time= 1.3min
# /glade/u/home/okyang/.local/lib/python3.10/site-packages/joblib/externals/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(

# %%
joblib.dump(rf_dtr, "modeldtr.pkl")
# Out:
# ['modeldtr.pkl']
# [CV] END bootstrap=True, max_depth=40, max_features=sqrt, min_samples_leaf=12, min_samples_split=5, n_estimators=300; total time=  39.0s
# [CV] END bootstrap=False, max_depth=25, max_features=sqrt, min_samples_leaf=8, min_samples_split=5, n_estimators=150; total time=  40.0s
# [CV] END bootstrap=False, max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=25, n_estimators=300; total time= 1.2min
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=25, n_estimators=100; total time=  13.2s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, min_samples_split=25, n_estimators=100; total time=  13.0s
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=12, min_samples_split=5, n_estimators=150; total time=  35.8s
# [CV] END bootstrap=False, max_depth=30, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=100; total time=  30.4s
# [CV] END bootstrap=False, max_depth=45, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  35.2s
# [CV] END bootstrap=False, max_depth=45, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  34.4s
# [CV] END bootstrap=False, max_depth=40, max_features=sqrt, min_samples_leaf=4, min_samples_split=15, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=8, min_samples_split=10, n_estimators=250; total time= 1.3min
# [CV] END bootstrap=True, max_depth=40, max_features=sqrt, min_samples_leaf=8, min_samples_split=10, n_estimators=200; total time=  31.1s
# [CV] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=12, min_samples_split=15, n_estimators=150; total time=  21.9s
# [CV] END bootstrap=False, max_depth=5, max_features=sqrt, min_samples_leaf=12, min_samples_split=10, n_estimators=250; total time=  51.3s
# [CV] END bootstrap=False, max_depth=40, max_features=sqrt, min_samples_leaf=8, min_samples_split=5, n_estimators=150; total time=  39.5s
# [CV] END bootstrap=False, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=False, max_depth=55, max_features=sqrt, min_samples_leaf=4, min_samples_split=25, n_estimators=150; total time=  40.9s
# [CV] END bootstrap=False, max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=25, n_estimators=300; total time= 1.1min
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=200; total time=  26.7s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=12, min_samples_split=15, n_estimators=300; total time=  40.1s
# [CV] END bootstrap=False, max_depth=30, max_features=sqrt, min_samples_leaf=12, min_samples_split=10, n_estimators=300; total time= 1.2min
# [CV] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=4, min_samples_split=25, n_estimators=150; total time=  24.3s
# [CV] END bootstrap=True, max_depth=40, max_features=sqrt, min_samples_leaf=12, min_samples_split=25, n_estimators=200; total time=  28.8s
# [CV] END bootstrap=False, max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=200; total time=  44.1s
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=12, min_samples_split=5, n_estimators=250; total time=  58.4s
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time= 1.4min
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=12, min_samples_split=25, n_estimators=200; total time=  47.9s
# [CV] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=150; total time=  23.2s
# [CV] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=150; total time=  25.5s
# [CV] END bootstrap=False, max_depth=30, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=100; total time=  26.6s
# [CV] END bootstrap=False, max_depth=30, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=100; total time=  26.7s
# [CV] END bootstrap=False, max_depth=30, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=100; total time=  29.3s
# [CV] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=8, min_samples_split=5, n_estimators=150; total time=  25.1s
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=12, min_samples_split=5, n_estimators=100; total time=  23.4s
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=12, min_samples_split=5, n_estimators=100; total time=  22.9s
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=12, min_samples_split=5, n_estimators=100; total time=  25.4s
# [CV] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=12, min_samples_split=15, n_estimators=200; total time=  29.5s
# [CV] END bootstrap=True, max_depth=45, max_features=sqrt, min_samples_leaf=8, min_samples_split=5, n_estimators=300; total time=  45.0s
# [CV] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=8, min_samples_split=10, n_estimators=200; total time=  54.3s
# [CV] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=8, min_samples_split=10, n_estimators=100; total time=  15.4s
# [CV] END bootstrap=True, max_depth=55, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  37.8s
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=8, min_samples_split=25, n_estimators=100; total time=  24.7s
# [CV] END bootstrap=True, max_depth=40, max_features=sqrt, min_samples_leaf=12, min_samples_split=5, n_estimators=300; total time=  44.5s
# [CV] END bootstrap=False, max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=25, n_estimators=300; total time= 1.0min
# [CV] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=25, n_estimators=100; total time=  17.8s
# [CV] END bootstrap=True, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=  43.3s
# [CV] END bootstrap=False, max_depth=30, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=100; total time=  27.1s
# [CV] END bootstrap=False, max_depth=40, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=250; total time= 1.2min
# [CV] END bootstrap=False, max_depth=45, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=  38.1s
# [CV] END bootstrap=True, max_depth=25, max_features=sqrt, min_samples_leaf=12, min_samples_split=10, n_estimators=100; total time=  13.1s
# [CV] END bootstrap=True, max_depth=25, max_features=sqrt, min_samples_leaf=12, min_samples_split=10, n_estimators=100; total time=  13.4s
# [CV] END bootstrap=True, max_depth=25, max_features=sqrt, min_samples_leaf=12, min_samples_split=10, n_estimators=100; total time=  14.6s
# [CV] END bootstrap=False, max_depth=35, max_features=sqrt, min_samples_leaf=8, min_samples_split=10, n_estimators=250; total time= 1.1min
# [CV] END bootstrap=True, max_depth=35, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=200; total time=  34.4s
# [CV] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=12, min_samples_split=15, n_estimators=150; total time=  19.1s
# [CV] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=12, min_samples_split=15, n_estimators=150; total time=  20.4s
# [CV] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=150; total time=  30.9s
# [CV] END bootstrap=True, max_depth=40, max_features=sqrt, min_samples_leaf=12, min_samples_split=25, n_estimators=250; total time=  32.7s
# [CV] END bootstrap=True, max_depth=40, max_features=sqrt, min_samples_leaf=12, min_samples_split=25, n_estimators=250; total time=  32.3s
# [CV] END bootstrap=False, max_depth=40, max_features=sqrt, min_samples_leaf=8, min_samples_split=5, n_estimators=150; total time=  43.0s
# [CV] END bootstrap=False, max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=25, n_estimators=200; total time=  43.0s
# [CV] END bootstrap=False, max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=25, n_estimators=200; total time=  41.8s
# [CV] END bootstrap=False, max_depth=55, max_features=sqrt, min_samples_leaf=4, min_samples_split=25, n_estimators=150; total time=  41.6s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=200; total time=  26.1s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=200; total time=  29.2s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=12, min_samples_split=15, n_estimators=300; total time=  43.8s
# [CV] END bootstrap=False, max_depth=30, max_features=sqrt, min_samples_leaf=12, min_samples_split=10, n_estimators=300; total time= 1.2min
# [CV] END bootstrap=True, max_depth=40, max_features=sqrt, min_samples_leaf=12, min_samples_split=25, n_estimators=200; total time=  27.1s
# [CV] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=250; total time=  37.3s
# [CV] END bootstrap=False, max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=200; total time=  42.7s
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=12, min_samples_split=5, n_estimators=250; total time= 1.1min
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=25, n_estimators=150; total time=  18.6s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=25, n_estimators=150; total time=  18.7s
# [CV] END bootstrap=False, max_depth=40, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=250; total time= 1.1min
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=12, min_samples_split=25, n_estimators=200; total time=  46.5s
# [CV] END bootstrap=False, max_depth=15, max_features=sqrt, min_samples_leaf=4, min_samples_split=15, n_estimators=300; total time= 1.4min
# [CV] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=8, min_samples_split=5, n_estimators=150; total time=  21.9s
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=15, n_estimators=300; total time= 1.6min
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=12, min_samples_split=25, n_estimators=150; total time=  34.9s

# %%
X_test = get_test_data('ssp245', solvers)
Y_test = create_predictdand_data(['ssp245'])
# Out:
# [CV] END bootstrap=True, max_depth=35, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=200; total time=  31.2s
# [CV] END bootstrap=True, max_depth=40, max_features=sqrt, min_samples_leaf=8, min_samples_split=10, n_estimators=200; total time=  31.0s
# [CV] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=150; total time=  28.6s
# [CV] END bootstrap=False, max_depth=5, max_features=sqrt, min_samples_leaf=12, min_samples_split=10, n_estimators=250; total time=  50.6s
# [CV] END bootstrap=True, max_depth=40, max_features=sqrt, min_samples_leaf=12, min_samples_split=25, n_estimators=250; total time=  37.0s
# [CV] END bootstrap=False, max_depth=30, max_features=sqrt, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time= 1.1min
# [CV] END bootstrap=False, max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=25, n_estimators=200; total time=  46.2s
# [CV] END bootstrap=False, max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=25, n_estimators=300; total time= 1.1min
# [CV] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=12, min_samples_split=5, n_estimators=100; total time=  13.8s
# [CV] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=12, min_samples_split=5, n_estimators=100; total time=  15.1s
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=12, min_samples_split=5, n_estimators=150; total time=  35.7s
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=12, min_samples_split=5, n_estimators=150; total time=  38.1s
# [CV] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=4, min_samples_split=25, n_estimators=150; total time=  22.7s
# [CV] END bootstrap=True, max_depth=15, max_features=sqrt, min_samples_leaf=4, min_samples_split=25, n_estimators=150; total time=  22.4s
# [CV] END bootstrap=True, max_depth=40, max_features=sqrt, min_samples_leaf=12, min_samples_split=25, n_estimators=200; total time=  26.7s
# [CV] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=250; total time=  36.5s
# [CV] END bootstrap=False, max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=200; total time=  47.8s
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time= 1.3min
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=8, min_samples_split=25, n_estimators=150; total time=  21.9s
# [CV] END bootstrap=False, max_depth=40, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=250; total time= 1.2min
# [CV] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=150; total time=  21.7s
# [CV] END bootstrap=False, max_depth=15, max_features=sqrt, min_samples_leaf=4, min_samples_split=15, n_estimators=300; total time= 1.5min
# [CV] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=8, min_samples_split=5, n_estimators=150; total time=  23.0s
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=15, n_estimators=300; total time= 1.5min
# [CV] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=12, min_samples_split=15, n_estimators=200; total time=  27.4s
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=12, min_samples_split=25, n_estimators=150; total time=  33.8s
# [CV] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=250; total time=  41.5s
# [CV] END bootstrap=False, max_depth=None, max_features=sqrt, min_samples_leaf=12, min_samples_split=5, n_estimators=250; total time=  59.2s
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=10, n_estimators=250; total time= 1.3min
# [CV] END bootstrap=False, max_depth=40, max_features=sqrt, min_samples_leaf=8, min_samples_split=15, n_estimators=250; total time= 1.1min
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=12, min_samples_split=25, n_estimators=200; total time=  50.3s
# [CV] END bootstrap=False, max_depth=15, max_features=sqrt, min_samples_leaf=4, min_samples_split=15, n_estimators=300; total time= 1.6min
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=4, min_samples_split=15, n_estimators=300; total time= 1.4min
# [CV] END bootstrap=True, max_depth=30, max_features=sqrt, min_samples_leaf=12, min_samples_split=15, n_estimators=200; total time=  25.8s
# [CV] END bootstrap=False, max_depth=20, max_features=sqrt, min_samples_leaf=12, min_samples_split=25, n_estimators=150; total time=  36.4s

# %%
tas_truth = Y_test["tas"]
pr_truth = Y_test["pr"]
pr90_truth = Y_test["pr90"]
dtr_truth = Y_test["diurnal_temperature_range"]

# %%
m_out_t = rf_tas.predict(X_test)

# %%
m_out_p = rf_pr.predict(X_test)
m_out_p90 = rf_pr90.predict(X_test)
m_out_d = rf_dtr.predict(X_test)

# %%
m_out_tas = m_out_t.reshape(86, 96, 144)
m_out_pr = m_out_p.reshape(86, 96, 144)
m_out_pr90 = m_out_p90.reshape(86, 96, 144)
m_out_dtr = m_out_d.reshape(86, 96, 144)

# %%
print(f"RMSE: {get_rmse(tas_truth[35], m_out_tas[35])}")
print(f"RMSE: {get_rmse(tas_truth[85], m_out_tas[85])}")
print(f"RMSE: {get_rmse(tas_truth[30:40], m_out_tas[30:40])}")
print(f"RMSE: {get_rmse(tas_truth[75:], m_out_tas[75:])}")
print(f"RMSE: {get_rmse(tas_truth[35:], m_out_tas[35:])}")
print("\n")

print(f"RMSE: {get_rmse(dtr_truth[35], m_out_dtr[35])}")
print(f"RMSE: {get_rmse(dtr_truth[85], m_out_dtr[85])}")
print(f"RMSE: {get_rmse(dtr_truth[30:40], m_out_dtr[30:40])}")
print(f"RMSE: {get_rmse(dtr_truth[75:], m_out_dtr[75:])}")
print(f"RMSE: {get_rmse(dtr_truth[35:], m_out_dtr[35:])}")
print("\n")

print(f"RMSE: {get_rmse(pr_truth[35], m_out_pr[35])}")
print(f"RMSE: {get_rmse(pr_truth[85], m_out_pr[85])}")
print(f"RMSE: {get_rmse(pr_truth[30:40], m_out_pr[30:40])}")
print(f"RMSE: {get_rmse(pr_truth[75:], m_out_pr[75:])}")
print(f"RMSE: {get_rmse(pr_truth[35:], m_out_pr[35:])}")
print("\n")

print(f"RMSE: {get_rmse(pr90_truth[35], m_out_pr90[35])}")
print(f"RMSE: {get_rmse(pr90_truth[85], m_out_pr90[85])}")
print(f"RMSE: {get_rmse(pr90_truth[30:40], m_out_pr90[30:40])}")
print(f"RMSE: {get_rmse(pr90_truth[75:], m_out_pr90[75:])}")
print(f"RMSE: {get_rmse(pr90_truth[35:], m_out_pr90[35:])}")
# Out:
# RMSE: 0.3933021822828737
# RMSE: 1.1830596314001198
# RMSE: [0.40568224 0.39790269 0.46512724 0.46625477 0.43156453 0.39330218
#  0.56938062 0.6807958  0.62321142 0.51160139]
# RMSE: [1.25981729 1.2926717  1.12531066 1.11802042 1.19958431 1.17783401
#  1.07573113 1.1128248  1.28374934 1.19935643 1.18305963]
# RMSE: [0.39330218 0.56938062 0.6807958  0.62321142 0.51160139 0.47193171
#  0.54437246 0.71965468 0.64657379 0.71002978 0.7973534  0.74567085
#  0.7488372  0.81121037 0.83688292 0.82793188 0.91397732 1.05265191
#  0.97172602 0.93468838 1.05432975 1.17001527 1.23199152 1.24678142
#  1.28269405 1.3277437  1.23008823 1.10743215 1.13112484 1.12798254
#  1.11720532 1.35894281 1.30787726 1.0939208  1.15175184 1.36768797
#  1.31542083 1.05788825 1.03431996 1.10250896 1.25981729 1.2926717
#  1.12531066 1.11802042 1.19958431 1.17783401 1.07573113 1.1128248
#  1.28374934 1.19935643 1.18305963]
#
#
# RMSE: 0.13556584887502277
# RMSE: 0.18643362986685963
# RMSE: [0.14038983 0.12830037 0.13390882 0.14206303 0.13740251 0.13556585
#  0.13680339 0.16375816 0.14795399 0.15144632]
# RMSE: [0.22005648 0.22877794 0.22665019 0.19722371 0.20334241 0.20081033
#  0.20035954 0.19614909 0.20329735 0.19717709 0.18643363]
# RMSE: [0.13556585 0.13680339 0.16375816 0.14795399 0.15144632 0.13977052
#  0.12625721 0.15936932 0.14089571 0.14535279 0.14079537 0.1389595
#  0.13646454 0.1596668  0.16403668 0.17139201 0.17018501 0.18629573
#  0.1639704  0.14864041 0.18094301 0.17395804 0.18614602 0.20937494
#  0.18810432 0.20717421 0.20768199 0.19348163 0.18392896 0.19062459
#  0.17959183 0.20002572 0.21454955 0.1948644  0.18184339 0.18821032
#  0.19971612 0.2044697  0.18080489 0.17668216 0.22005648 0.22877794
#  0.22665019 0.19722371 0.20334241 0.20081033 0.20035954 0.19614909
#  0.20329735 0.19717709 0.18643363]
#
#
# RMSE: 0.4296097732391328
# RMSE: 0.6595618198014065
# RMSE: [0.4933901  0.46827601 0.51703486 0.58667433 0.39037341 0.42960977
#  0.64579625 0.79784047 0.43427126 0.51760763]
# RMSE: [0.66503842 0.78319108 0.51731549 0.45222032 0.70399087 0.49660301
#  0.55331457 0.67880117 0.63277416 0.58167536 0.65956182]
# RMSE: [0.42960977 0.64579625 0.79784047 0.43427126 0.51760763 0.49653625
#  0.41766481 0.669828   0.38313023 0.63183199 0.63202707 0.45149376
#  0.4591024  0.57588458 0.64218486 0.5168152  0.50949106 0.82648639
#  0.45798927 0.53706686 0.41536408 0.44259076 0.53385013 0.63090814
#  0.62257134 0.59012976 0.465332   0.64496244 0.48512087 0.62529407
#  0.85616873 0.8207055  0.91277734 0.65939493 0.64402467 0.92335815
#  0.49689838 0.52831681 0.52390859 0.470017   0.66503842 0.78319108
#  0.51731549 0.45222032 0.70399087 0.49660301 0.55331457 0.67880117
#  0.63277416 0.58167536 0.65956182]
#
#
# RMSE: 1.3045428887404436
# RMSE: 1.9458881237594925
# RMSE: [1.43133476 1.37386904 1.57862333 1.66761948 1.22195813 1.30454289
#  1.8492143  2.21636416 1.44394714 1.49268869]
# RMSE: [1.85591362 2.25140371 1.47043048 1.30483118 2.05230307 1.66247997
#  1.58884684 1.83494842 1.75350612 1.67786571 1.94588812]
# RMSE: [1.30454289 1.8492143  2.21636416 1.44394714 1.49268869 1.42390086
#  1.26196695 1.89568249 1.19984883 1.77855978 1.92465864 1.38186169
#  1.35657508 1.61085592 1.88973216 1.44124267 1.53976323 2.35067023
#  1.41123872 1.52012082 1.30211488 1.29974891 1.61042038 1.87753254
#  1.78894375 1.80646511 1.3595025  1.78323733 1.38526555 1.83663196
#  2.38129127 2.24721683 2.66991794 1.88182704 1.87786426 2.46568374
#  1.53523181 1.45932051 1.50022712 1.36120817 1.85591362 2.25140371
#  1.47043048 1.30483118 2.05230307 1.66247997 1.58884684 1.83494842
#  1.75350612 1.67786571 1.94588812]
